# %%
from pyresample.bilinear import XArrayBilinearResampler
# Out:
# /var/folders/ps/bdhslmwj4t16q5_v16j9hwmc0000gt/T/ipykernel_93821/1431797386.py:1: UserWarning: XArray, dask, and/or zarr not found, XArrayBilinearResampler won't be available.
#   from pyresample.bilinear import XArrayBilinearResampler
