# %%
import pandas as pd

# %%
debug_dataset = pd.read_parquet("/Volumes/University_stuff/Code_Projects/Glaciation_time_estimator/Debug_data/np/20070101.0000_20070115.0000/Agg_03_T_12_06.parquet")

# %%
# Out:
# 0        [165125.3, 168900.95, 159965.1, 164012.47, 141...
# 1        [256223.88, 263330.12, 281354.88, 276092.53, 2...
# 2        [111412.36, 84091.766, 57108.08, 30404.45, 101...
# 3        [121620.805, 105387.92, 164692.95, 174953.31, ...
# 4        [60175.383, 61218.418, 55728.03, 52460.016, 49...
#                                ...
# 13769          [6964.586, 5627.1445, 4757.9355, 6063.7715]
# 13770          [2755.4253, 3111.644, 1910.4766, 1912.2946]
# 13771               [5119.472, 5820.237, 8894.727, 4753.3]
# 13772           [6198.4043, 15415.714, 16370.25, 17413.71]
# 13773         [3300.1184, 4105.1943, 3553.8555, 7332.7705]
# Name: size_hist_km, Length: 13774, dtype: object

# %%
debug_dataset.apply(lambda row: (row["size_hist_km_debug"] == row["size_hist_km"]).all(), axis=1).value_counts()
# Out:
# True    13774
# Name: count, dtype: int64
