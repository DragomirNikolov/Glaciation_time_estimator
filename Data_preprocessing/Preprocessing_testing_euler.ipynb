# %%
import os
import sys
parent_dir = os.path.dirname(os.environ["GTE_DIR"].replace("Glaciation_time_estimator",""))
GTE_DIR=os.environ["GTE_DIR"]
sys.path.insert(0, parent_dir)
from Glaciation_time_estimator.Auxiliary_func.config_reader import read_config
from Glaciation_time_estimator.Data_preprocessing.Preprocessing_pipeline import preprocessing_pipeline

# %%
config = read_config("/cluster/work/climate/dnikolo/n2o/Glaciation_time_estimator/configs/April_testing/euler_template.yaml")

# %%
preprocessing_pipeline(config)
# Out:
# Generating target filenames
# Target filenames generated
# Resampling needed files
# /cluster/work/climate/dnikolo/n2o/Glaciation_time_estimator/Data_preprocessing/Preprocessing_pipeline.py:226: UserWarning: Working without multiprocessing
#   warnings.warn("Working without multiprocessing")
# Formated day 0 in -90.04s starting with fp: /nfs/n2o/wolke_scratch/dnikolo/CLAAS_Data/np/2007/02/01/CTXin20070201000000405SVMSG01MD.nc
# Formated day 1 in -1.09s starting with fp: /nfs/n2o/wolke_scratch/dnikolo/CLAAS_Data/np/2007/02/02/CTXin20070202000000405SVMSG01MD.nc
# Aggregated day 0/2 in 297.24s
# Starting with /nfs/n2o/wolke_scratch/dnikolo/CLAAS_Data/Resampled_Data/np/2007/02/01/Agg_03_20070201000000.nc
# Aggregated day 1/2 in 3.2s
# Starting with /nfs/n2o/wolke_scratch/dnikolo/CLAAS_Data/Resampled_Data/np/2007/02/02/Agg_03_20070202000000.nc
# /cluster/work/climate/dnikolo/n2o/Glaciation_time_estimator/Data_preprocessing/Preprocessing_pipeline.py:226: UserWarning: Working without multiprocessing
#   warnings.warn("Working without multiprocessing")
# Formated day 0 in -94.52s starting with fp: /nfs/n2o/wolke_scratch/dnikolo/CLAAS_Data/sp/2007/02/01/CTXin20070201000000405SVMSG01MD.nc
# Formated day 1 in -1.04s starting with fp: /nfs/n2o/wolke_scratch/dnikolo/CLAAS_Data/sp/2007/02/02/CTXin20070202000000405SVMSG01MD.nc
# Aggregated day 0/2 in 298.58s
# Starting with /nfs/n2o/wolke_scratch/dnikolo/CLAAS_Data/Resampled_Data/sp/2007/02/01/Agg_03_20070201000000.nc
# Aggregated day 1/2 in 3.13s
# Starting with /nfs/n2o/wolke_scratch/dnikolo/CLAAS_Data/Resampled_Data/sp/2007/02/02/Agg_03_20070202000000.nc
# Total resampling + agg time = 789.99
# Needed files resampled. Start filtering
# Filtered np in 147.06s
# Filtered sp in 147.54s
# Filtering complete
